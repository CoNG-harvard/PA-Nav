# %% [markdown]
# # Utilities to load the map and scenario files from GPPC repo

# %%
from matplotlib import pyplot as plt
from mapLoaders import TwoDMap

# %%
loader = TwoDMap('arena.map')
plt.imshow(loader.map)

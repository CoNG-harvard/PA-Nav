# %% [markdown]
# # Development: Integrate PIBT Deadlock Resolution in RCA

# %%
import sys
sys.path.append('../')

sys.path.append('../../')
import numpy as np
import cvxpy as cp
from matplotlib import pyplot as plt
from panav.environment.env import MultiTunnelEnv
from panav.hybrid import HybridGraph

from panav.viz import draw_env

import shapely

from panav.ORCA import Ordered_Agent

# %load_ext autoreload
# %autoreload 2

# %load_ext snakeviz

# %%
bloating_r = 0.5
vmax = 1.0

N = 40


results = []

env_name = "MultiTunnel"


env = MultiTunnelEnv(n_tunnel = 4, tunnel_width = bloating_r*2.5,limits=[(-12,12),(-20,20)], N_agent = N)
HG = HybridGraph(env,bloating_r)

# For development purposes, force the soft edge weights to be zero, so that the agents strictly don't have head on collisions.

for e in HG.edges:
    if HG.edges[e]['type']=='soft':
        # HG.edges[e]['weight'] = 0
        pass
# Out:
# /Users/tianpengzhang/opt/miniconda3/envs/PA-Nav/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)

# %%
from panav.TrafficAwarePlanning import traffic_aware_HG_plan
paths = traffic_aware_HG_plan(HG)

ref_plan = [np.array([HG.node_loc(u) for u in path]).T for path in paths]

# %%
plans = ref_plan

tau = 1.0 # The safe time interval. Can be generously long.
exec_tau = 0.95 * tau # Leaving a slight horizon margin helps avoid numerical inaccuracy in CVXPY optimization results.
agents = np.arange(N)
start_locs = env.starts
goal_locs = env.goals
# The execution time of ORCA velocity.
# Should be much shorter than the safe interval tau.

pos = []

v_prefs = [np.zeros(start_locs[0].shape) for a in agents]

protocol = 0

orcas = [Ordered_Agent(protocol,tau,bloating_r,vmax,p,init_v = None) 
         for p in start_locs]

# We will assume agent i is ranked i among the agents when dealing with conflicts.

curr_wp_index = [0 for a in agents]

def calc_pref(agent):

    wp = plans[agent][:,curr_wp_index[agent]]
    # See if the agent has reached the current waypoint.
    if np.linalg.norm(wp-orcas[agent].p)<= bloating_r:  
        curr_wp_index[agent] = \
        np.min([curr_wp_index[agent]+1,   
                plans[agent].shape[1]-1
                                ])
        
        wp = plans[agent][:,curr_wp_index[agent]]
        
    to_wp = wp-orcas[agent].p
    
    v_prefs[agent] = to_wp/tau if tau*vmax > np.linalg.norm(to_wp) else vmax *  to_wp/(np.linalg.norm(to_wp)+1e-5)

def PIBT(a):

    P = []
    C = []

    for nb in range(len(orcas)):
        # Find all agents in the that could collide with a in the next tau seconds.
        if nb!=a and np.linalg.norm(orcas[nb].p-orcas[a].p)<orcas[nb].bloating_r+orcas[a].bloating_r\
                                                  + 2 * vmax * tau:
            if np.linalg.norm(orcas[nb].p-orcas[a].p)<orcas[nb].bloating_r+orcas[a].bloating_r:
                print("Soft Collision. Agents ",a,nb,"Dist",np.linalg.norm(orcas[nb].p-orcas[a].p))
                raise Exception
            if orcas[nb].v is None:
                C.append(nb)
            else:
                P.append(nb)
            

    # print("Agent",a,"P",P,"C",C)

    candidate_v_pref = [] 

    for theta in np.pi * np.linspace(0,2,4)[:-1]:
            # Rotate v_pref clockwise by theta.
            v_right = np.array([[np.cos(-theta),-np.sin(-theta)],
                                [np.sin(-theta),np.cos(-theta)]]).dot(v_prefs[a])
            candidate_v_pref.append(v_right)

    candidate_v_pref.append(np.array([0,0])) # Always have zero velocity as a default 
    
    for i,v_pref in enumerate(candidate_v_pref):
        orcas[a].update_v(v_pref,env.obstacles,[orcas[b] for b in P]) 
        if orcas[a].v is None:
            # print("Agent",a,"infeasible")
            return False
        
        print("Agent",a,"v_pref",i,"feasible",'v',orcas[a].v,'v_opt',orcas[a].v_opt)
        
        children_valid = True
        for c in C:
            if orcas[c].v is None:
                print("Parent agent",a," calling PIBT for agent",c,"in recursive call")
                children_valid = PIBT(c)
                if not children_valid:
                    break
        
        if children_valid:
            return True

    orcas[a].v = None
    return False

for _ in range(200):
    print("################### Time step {} ################".format(_))
    pos.append(np.array([a.p for a in orcas]))
       
    for a in agents:
        # print("Agent",a)

        # Compute the preferred velocity.
        calc_pref(a)  


        
        
    
    for a in agents:
        if orcas[a].v is None:
            print("PIBT for agent",a,"in outer loop")
            valid = PIBT(a)
            print('Agent',a,'Valid',valid," in outer loop")
    
    # We assume agent a is ranked a among the agents when dealing with conflicts.
    
    # Execute the safe velocity.
    all_reached = True
    
    for a in agents:
        dist2goal = np.linalg.norm(orcas[a].p - goal_locs[a])
        # print(a,dist2goal)

        if dist2goal>=1*bloating_r:
            orcas[a].p += orcas[a].v*exec_tau
            all_reached = False
            # Reset all agent's v to be None
            orcas[a].v = None
        else:
            orcas[a].v = orcas[a].v_opt = np.array([0,0])
    if all_reached:
        break
# Out:
# ################### Time step 0 ################
# ################### Time step 1 ################
# PIBT for agent 0 in outer loop
# Agent 0 v_pref 0 feasible v [-0.43696 -0.89948] v_opt [-0.43696 -0.89948]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 v_pref 0 feasible v [-0.49262 -0.87024] v_opt [-0.49262 -0.87024]
# Parent agent 1  calling PIBT for agent 2 in recursive call
# Agent 2 v_pref 0 feasible v [-0.32552 -0.94554] v_opt [-0.32552 -0.94554]
# Parent agent 2  calling PIBT for agent 3 in recursive call
# Agent 3 v_pref 0 feasible v [-0.64568 -0.76361] v_opt [-0.64568 -0.76361]
# Parent agent 3  calling PIBT for agent 4 in recursive call
# Agent 4 v_pref 0 feasible v [-0.74674 -0.66511] v_opt [-0.74674 -0.66511]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Agent 5 v_pref 0 feasible v [-0.85797 -0.5137 ] v_opt [-0.85797 -0.5137 ]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 v_pref 0 feasible v [-0.95602 -0.29329] v_opt [-0.95602 -0.29329]
# Parent agent 6  calling PIBT for agent 7 in recursive call
# Agent 7 v_pref 0 feasible v [-0.99989 -0.01482] v_opt [-0.99989 -0.01482]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 v_pref 0 feasible v [-0.96368  0.26706] v_opt [-0.96368  0.26706]
# Parent agent 8  calling PIBT for agent 9 in recursive call
# Agent 9 v_pref 0 feasible v [-0.86912  0.4946 ] v_opt [-0.86912  0.4946 ]
# Parent agent 9  calling PIBT for agent 10 in recursive call
# Agent 10 v_pref 0 feasible v [-0.7578   0.65249] v_opt [-0.7578   0.65249]
# Parent agent 10  calling PIBT for agent 11 in recursive call
# Agent 11 v_pref 0 feasible v [-0.96368 -0.26706] v_opt [-0.96368 -0.26706]
# Parent agent 11  calling PIBT for agent 12 in recursive call
# Agent 12 v_pref 0 feasible v [-0.99989  0.01482] v_opt [-0.99989  0.01482]
# Parent agent 12  calling PIBT for agent 13 in recursive call
# Agent 13 v_pref 0 feasible v [-0.95602  0.29329] v_opt [-0.95602  0.29329]
# Parent agent 13  calling PIBT for agent 14 in recursive call
# Agent 14 v_pref 0 feasible v [-0.85797  0.5137 ] v_opt [-0.85797  0.5137 ]
# Parent agent 14  calling PIBT for agent 15 in recursive call
# Agent 15 v_pref 0 feasible v [-0.74674  0.66511] v_opt [-0.74674  0.66511]
# Parent agent 15  calling PIBT for agent 16 in recursive call
# Agent 16 v_pref 0 feasible v [-0.64568  0.76361] v_opt [-0.64568  0.76361]
# Parent agent 16  calling PIBT for agent 17 in recursive call
# Agent 17 v_pref 0 feasible v [-0.56126  0.82764] v_opt [-0.56126  0.82764]
# Parent agent 17  calling PIBT for agent 18 in recursive call
# Agent 18 v_pref 0 feasible v [-0.29856  0.95439] v_opt [-0.29856  0.95439]
# Parent agent 18  calling PIBT for agent 19 in recursive call
# Agent 19 v_pref 0 feasible v [-0.43696  0.89948] v_opt [-0.43696  0.89948]
# Agent 0 Valid True  in outer loop
# PIBT for agent 20 in outer loop
# Agent 20 v_pref 0 feasible v [ 0.84671 -0.53206] v_opt [ 0.84671 -0.53206]
# Parent agent 20  calling PIBT for agent 21 in recursive call
# Agent 21 v_pref 0 feasible v [ 0.9478  -0.31887] v_opt [ 0.9478  -0.31887]
# Parent agent 21  calling PIBT for agent 22 in recursive call
# Agent 22 v_pref 0 feasible v [ 0.99901 -0.04443] v_opt [ 0.99901 -0.04443]
# Parent agent 22  calling PIBT for agent 23 in recursive call
# Agent 23 v_pref 0 feasible v [0.97071 0.24023] v_opt [0.97071 0.24023]
# Parent agent 23  calling PIBT for agent 24 in recursive call
# Agent 24 v_pref 0 feasible v [0.88011 0.47476] v_opt [0.88011 0.47476]
# Parent agent 24  calling PIBT for agent 25 in recursive call
# Agent 25 v_pref 0 feasible v [0.76896 0.6393 ] v_opt [0.76896 0.6393 ]
# Parent agent 25  calling PIBT for agent 26 in recursive call
# Agent 26 v_pref 0 feasible v [0.66491 0.74692] v_opt [0.66491 0.74692]
# Parent agent 26  calling PIBT for agent 27 in recursive call
# Agent 27 v_pref 0 feasible v [0.57706 0.8167 ] v_opt [0.57706 0.8167 ]
# Parent agent 27  calling PIBT for agent 28 in recursive call
# Agent 28 v_pref 0 feasible v [ 0.36102 -0.93256] v_opt [ 0.36102 -0.93256]
# Parent agent 28  calling PIBT for agent 29 in recursive call
# Agent 29 v_pref 0 feasible v [ 0.40002 -0.91651] v_opt [ 0.40002 -0.91651]
# Parent agent 29  calling PIBT for agent 30 in recursive call
# Agent 30 v_pref 0 feasible v [ 0.44736 -0.89436] v_opt [ 0.44736 -0.89436]
# Parent agent 30  calling PIBT for agent 31 in recursive call
# Agent 31 v_pref 0 feasible v [ 0.50542 -0.86287] v_opt [ 0.50542 -0.86287]
# Parent agent 31  calling PIBT for agent 32 in recursive call
# Agent 32 v_pref 0 feasible v [-0.42044  0.39184] v_opt [-0.42044  0.39184]
# Parent agent 32  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [ 0.66491 -0.74692] v_opt [ 0.66491 -0.74692]
# Parent agent 33  calling PIBT for agent 34 in recursive call
# Agent 34 v_pref 0 feasible v [ 0.76896 -0.6393 ] v_opt [ 0.76896 -0.6393 ]
# Parent agent 34  calling PIBT for agent 35 in recursive call
# Agent 35 v_pref 0 feasible v [ 0.88011 -0.47476] v_opt [ 0.88011 -0.47476]
# Parent agent 35  calling PIBT for agent 36 in recursive call
# Agent 36 v_pref 0 feasible v [ 0.97071 -0.24023] v_opt [ 0.97071 -0.24023]
# Parent agent 36  calling PIBT for agent 37 in recursive call
# Agent 37 v_pref 0 feasible v [0.99901 0.04443] v_opt [0.99901 0.04443]
# Parent agent 37  calling PIBT for agent 38 in recursive call
# Agent 38 v_pref 0 feasible v [0.9478  0.31887] v_opt [0.9478  0.31887]
# Parent agent 38  calling PIBT for agent 39 in recursive call
# Agent 39 v_pref 0 feasible v [0.84671 0.53206] v_opt [0.84671 0.53206]
# Agent 20 Valid True  in outer loop
# ################### Time step 2 ################
# PIBT for agent 0 in outer loop
# Agent 0 v_pref 0 feasible v [-0.43696 -0.89948] v_opt [-0.43696 -0.89948]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 v_pref 0 feasible v [-0.49262 -0.87024] v_opt [-0.49262 -0.87024]
# Parent agent 1  calling PIBT for agent 2 in recursive call
# Agent 2 v_pref 0 feasible v [-0.32552 -0.94554] v_opt [-0.32552 -0.94554]
# Parent agent 2  calling PIBT for agent 3 in recursive call
# Agent 3 v_pref 0 feasible v [-0.64568 -0.76361] v_opt [-0.64568 -0.76361]
# Parent agent 3  calling PIBT for agent 4 in recursive call
# Agent 4 v_pref 0 feasible v [-0.74674 -0.66511] v_opt [-0.74674 -0.66511]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Agent 5 v_pref 0 feasible v [-0.85797 -0

# Parent agent 11  calling PIBT for agent 12 in recursive call
# Agent 12 v_pref 0 feasible v [-0.03623  0.02169] v_opt [-0.03623  0.02169]
# Parent agent 12  calling PIBT for agent 13 in recursive call
# Agent 13 v_pref 0 feasible v [-0.18651  0.73745] v_opt [-0.18651  0.73745]
# Parent agent 13  calling PIBT for agent 14 in recursive call
# Agent 14 v_pref 0 feasible v [-0.56886  0.46728] v_opt [-0.56886  0.46728]
# Parent agent 14  calling PIBT for agent 15 in recursive call
# Agent 15 v_pref 0 feasible v [-0.65219  0.49868] v_opt [-0.65219  0.49868]
# Parent agent 15  calling PIBT for agent 16 in recursive call
# Agent 16 v_pref 0 feasible v [-0.59992  0.76777] v_opt [-0.59992  0.76777]
# Parent agent 16  calling PIBT for agent 17 in recursive call
# Agent 17 v_pref 0 feasible v [-0.52699  0.75437] v_opt [-0.52699  0.75437]
# Parent agent 17  calling PIBT for agent 18 in recursive call
# Agent 18 v_pref 0 feasible v [-0.29856  0.95439] v_opt [-0.29856  0.95439]
# Parent agent 18  calling PIBT for agent 19 in recursive call
# Agent 19 v_pref 0 feasible v [-0.43696  0.89948] v_opt [-0.43696  0.89948]
# Agent 11 Valid True  in outer loop
# PIBT for agent 20 in outer loop
# Agent 20 v_pref 0 feasible v [ 0.591   -0.53985] v_opt [ 0.591   -0.53985]
# Parent agent 20  calling PIBT for agent 21 in recursive call
# Agent 21 v_pref 0 feasible v [-0.05319 -0.87553] v_opt [-0.05319 -0.87553]
# Parent agent 21  calling PIBT for agent 22 in recursive call
# Agent 22 v_pref 0 feasible v [ 0.07818 -0.83967] v_opt [ 0.07818 -0.83967]
# Parent agent 22  calling PIBT for agent 23 in recursive call
# Agent 23 v_pref 0 feasible v [-0.16314  0.73311] v_opt [-0.16314  0.73311]
# Parent agent 23  calling PIBT for agent 24 in recursive call
# Agent 24 v_pref 0 feasible v [0.02378 0.99972] v_opt [0.02378 0.99972]
# Parent agent 24  calling PIBT for agent 25 in recursive call
# Agent 25 v_pref 0 feasible v [0.46322 0.63924] v_opt [0.46322 0.63924]
# Parent agent 25  calling PIBT for agent 26 in recursive call
# Agent 26 v_pref 0 feasible v [0.46241 0.70621] v_opt [0.46241 0.70621]
# Parent agent 26  calling PIBT for agent 27 in recursive call
# Agent 27 v_pref 0 feasible v [0.49879 0.72859] v_opt [0.49879 0.72859]
# Agent 20 Valid True  in outer loop
# PIBT for agent 28 in outer loop
# Agent 28 v_pref 0 feasible v [ 0.36102 -0.93256] v_opt [ 0.36102 -0.93256]
# Parent agent 28  calling PIBT for agent 29 in recursive call
# Agent 29 v_pref 0 feasible v [ 0.40002 -0.91651] v_opt [ 0.40002 -0.91651]
# Parent agent 29  calling PIBT for agent 30 in recursive call
# Agent 30 v_pref 0 feasible v [ 0.44736 -0.89435] v_opt [ 0.44736 -0.89435]
# Parent agent 30  calling PIBT for agent 31 in recursive call
# Agent 31 v_pref 0 feasible v [ 0.50542 -0.86287] v_opt [ 0.50542 -0.86287]
# Parent agent 31  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [ 0.66491 -0.74692] v_opt [ 0.66491 -0.74692]
# Parent agent 33  calling PIBT for agent 34 in recursive call
# Agent 34 v_pref 0 feasible v [ 0.76895 -0.6393 ] v_opt [ 0.76895 -0.6393 ]
# Parent agent 34  calling PIBT for agent 35 in recursive call
# infeasible
# Agent 34 v_pref 1 feasible v [-0.81055 -0.58568] v_opt [-0.81055 -0.58568]
# Parent agent 34  calling PIBT for agent 35 in recursive call
# Agent 35 v_pref 0 feasible v [ 0.60359 -0.40128] v_opt [ 0.60359 -0.40128]
# Parent agent 35  calling PIBT for agent 36 in recursive call
# Agent 36 v_pref 0 feasible v [ 0.13836 -0.61532] v_opt [ 0.13836 -0.61532]
# Parent agent 36  calling PIBT for agent 37 in recursive call
# Agent 37 v_pref 0 feasible v [ 0.20904 -0.61842] v_opt [ 0.20904 -0.61842]
# Parent agent 37  calling PIBT for agent 38 in recursive call
# Agent 38 v_pref 0 feasible v [0.49772 0.68938] v_opt [0.49772 0.68938]
# Parent agent 38  calling PIBT for agent 39 in recursive call
# Agent 39 v_pref 0 feasible v [0.67093 0.61055] v_opt [0.67093 0.61055]
# Agent 28 Valid True  in outer loop
# PIBT for agent 32 in outer loop
# Agent 32 v_pref 0 feasible v [0.3763 0.9265] v_opt [0.3763 0.9265]
# Agent 32 Valid True  in outer loop
# ################### Time step 8 ################
# PIBT for agent 0 in outer loop
# Agent 0 v_pref 0 feasible v [-0.43696 -0.89948] v_opt [-0.43696 -0.89948]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 v_pref 0 feasible v [-0.49262 -0.87024] v_opt [-0.49262 -0.87024]
# Parent agent 1  calling PIBT for agent 2 in recursive call
# Agent 2 v_pref 0 feasible v [-0.32552 -0.94554] v_opt [-0.32552 -0.94554]
# Parent agent 2  calling PIBT for agent 3 in recursive call
# Agent 3 v_pref 0 feasible v [-0.64568 -0.7636 ] v_opt [-0.64568 -0.7636 ]
# Parent agent 3  calling PIBT for agent 4 in recursive call
# infeasible
# Agent 3 v_pref 1 feasible v [-0.33846  0.94098] v_opt [-0.33846  0.94098]
# Parent agent 3  calling PIBT for agent 4 in recursive call
# Agent 4 v_pref 0 feasible v [-0.19366 -0.92156] v_opt [-0.19366 -0.92156]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# infeasible
# Agent 4 v_pref 1 feasible v [-0.19366  0.63274] v_opt [-0.19366  0.63274]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Agent 5 v_pref 0 feasible v [-0.46835 -0.015  ] v_opt [-0.46835 -0.015  ]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 v_pref 0 feasible v [-0.04463  0.47581] v_opt [-0.04463  0.47581]
# Parent agent 6  calling PIBT for agent 7 in recursive call
# Agent 7 v_pref 0 feasible v [-0.00294  0.46546] v_opt [-0.00294  0.46546]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 v_pref 0 feasible v [-0.27071  0.85811] v_opt [-0.27071  0.85811]
# Parent agent 8  calling PIBT for agent 9 in recursive call
# Agent 9 v_pref 0 feasible v [-0.74297  0.37391] v_opt [-0.74297  0.37391]
# Parent agent 9  calling PIBT for agent 10 in recursive call
# infeasible
# Agent 9 v_pref 1 feasible v [0.86377 0.50388] v_opt [0.86377 0.50388]
# Parent agent 9  calling PIBT for agent 10 in recursive call
# Agent 10 v_pref 0 feasible v [-0.02271  0.53422] v_opt [-0.02271  0.53422]
# Agent 0 Valid True  in outer loop
# PIBT for agent 11 in outer loop
# Agent 11 v_pref 0 feasible v [-0.99999  0.0038 ] v_opt [-0.99999  0.0038 ]
# Parent agent 11  calling PIBT for agent 12 in recursive call
# Agent 12 v_pref 0 feasible v [-0.00181  0.91357] v_opt [-0.00181  0.91357]
# Parent agent 12  calling PIBT for agent 13 in recursive call
# Agent 13 v_pref 0 feasible v [0.07838 0.53163] v_opt [0.07838 0.53163]
# Parent agent 13  calling PIBT for agent 14 in recursive call
# Agent 14 v_pref 0 feasible v [-0.66073  0.61716] v_opt [-0.66073  0.61716]
# Parent agent 14  calling PIBT for agent 15 in recursive call
# Agent 15 v_pref 0 feasible v [-0.54516  0.57681] v_opt [-0.54516  0.57681]
# Parent agent 15  calling PIBT for agent 16 in recursive call
# Agent 16 v_pref 0 feasible v [-0.52107  0.75455] v_opt [-0.52107  0.75455]
# Parent agent 16  calling PIBT for agent 17 in recursive call
# Agent 17 v_pref 0 feasible v [-0.50445  0.75497] v_opt [-0.50445  0.75497]
# Parent agent 17  calling PIBT for agent 18 in recursive call
# Agent 18 v_pref 0 feasible v [-0.29856  0.95439] v_opt [-0.29856  0.95439]
# Parent agent 18  calling PIBT for agent 19 in recursive call
# Agent 19 v_pref 0 feasible v [-0.43696  0.89948] v_opt [-0.43696  0.89948]
# Agent 11 Valid True  in outer loop
# PIBT for agent 20 in outer loop
# Agent 20 v_pref 0 feasible v [ 0.47983 -0.1098 ] v_opt [ 0.47983 -0.1098 ]
# Parent agent 20  calling PIBT for agent 21 in recursive call
# Agent 21 v_pref 0 feasible v [0.03825 0.43024] v_opt [0.03825 0.43024]
# Parent agent 21  calling PIBT for agent 22 in recursive call
# Agent 22 v_pref 0 feasible v [0.00391 0.42086] v_opt [0.00391 0.42086]
# Parent agent 22  calling PIBT for agent 23 in recursive call
# Agent 23 v_pref 0 feasible v [0.04805 0.62611] v_opt [0.04805 0.62611]
# Parent agent 23  calling PIBT for agent 24 in recursive call
# Agent 24 v_pref 0 feasible v [0.21822 0.8386 ] v_opt [0.21822 0.8386 ]
# Parent agent 24  calling PIBT for agent 25 in recursive call
# Agent 25 v_pref 0 feasible v [0.04742 0.6257 ] v_opt [0.04742 0.6257 ]
# Parent agent 25  calling PIBT for agent 26 in recursive call
# Agent 26 v_pref 0 feasible v [0.05361 0.7021 ] v_opt [0.05361 0.7021 ]
# Parent agent 26  calling PIBT for agent 27 in recursive call
# Agent 27 v_pref 0 feasible v [0.35143 0.47595] v_opt [0.35143 0.47595]
# Agent 20 Valid True  in outer loop
# PIBT for agent 28 in outer loop
# Agent 28 v_pref 0 feasible v [ 0.36102 -0.93256] v_opt [ 0.36102 -0.93256]
# Parent agent 28  calling PIBT for agent 29 in recursive call
# Agent 29 v_pref 0 feasible v [ 0.40002 -0.91651] v_opt [ 0.40002 -0.91651]
# Parent agent 29  calling PIBT for agent 30 in recursive call
# Agent 30 v_pref 0 feasible v [ 0.44736 -0.89435] v_opt [ 0.44736 -0.89435]
# Parent agent 30  calling PIBT for agent 31 in recursive call
# Agent 31 v_pref 0 feasible v [ 0.50542 -0.86287] v_opt [ 0.50542 -0.86287]
# Parent agent 31  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [ 0.66491 -0.74692] v_opt [ 0.66491 -0.74692]
# Parent agent 33  calling PIBT for agent 34 in recursive call
# Agent 34 v_pref 0 feasible v [ 0.71439 -0.48025] v_opt [ 0.71439 -0.48025]
# Parent agent 34  calling PIBT for agent 35 in recursive call
# Agent 35 v_pref 0 feasible v [0.44119 0.04677] v_opt [0.44119 0.04677]
# Parent agent 35  calling PIBT for agent 36 in recursive call
# Agent 36 v_pref 0 feasible v [-0.09116  0.49902] v_opt [-0.09116  0.49902]
# Parent agent 36  calling PIBT for agent 37 in recursive call
# Agent 37 v_pref 0 feasible v [0.01045 0.50276] v_opt [0.01045 0.50276]
# Parent agent 37  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 37 v_pref 1 feasible v [ 0.01045 -0.63915] v_opt [ 0.01045 -0.63915]
# Parent agent 37  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 37 v_pref 2 feasible v [-0.93806 -0.34647] v_opt [-0.93806 -0.34647]
# Parent agent 37  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 37 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 37  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 36 v_pref 1 feasible v [ 0.00692 -0.73414] v_opt [ 0.00692 -0.73414]
# Parent agent 36  calling PIBT for agent 37 in recursive call
# Agent 37 v_pref 0 feasible v [ 0.01045 -0.73401] v_opt [ 0.01045 -0.73401]
# Parent agent 37  calling PIBT for agent 38 in recursive call
# Agent 38 v_pref 0 feasible v [0.65012 0.06758] v_opt [0.65012 0.06758]
# Parent agent 38  calling PIBT for agent 39 in recursive call
# Agent 39 v_pref 0 feasible v [0.35817 0.20046] v_opt [0.35817 0.20046]
# Agent 28 Valid True  in outer loop
# PIBT for agent 32 in outer loop
# Agent 32 v_pref 0 feasible v [0.3763 0.9265] v_opt [0.3763 0.9265]
# Agent 32 Valid True  in outer loop
# ################### Time step 9 ################
# PIBT for agent 0 in outer loop
# Agent 0 v_pref 0 feasible v [-0.43696 -0.89948] v_opt [-0.43696 -0.89948]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 v_pref 0 feasible v [-0.49262 -0.87024] v_opt [-0.49262 -0.87024]
# Parent agent 1  calling PIBT for agent 2 in recursive call
# Agent 2 v_pref 0 feasible v [-0.32552 -0.94554] v_opt [-0.32552 -0.94554]
# Parent agent 2  calling PIBT for agent 3 in recursive call
# Agent 3 v_pref 0 feasible v [-0.40058 -0.91626] v_opt [-0.40058 -0.91626]
# Parent agent 3  calling PIBT for agent 4 in recursive call
# infeasible
# Agent 3 v_pref 1 feasible v [-0.72459  0.68918] v_opt [-0.72459  0.68918]
# Parent agent 3  calling PIBT for agent 4 in recursive call
# Agent 4 v_pref 0 feasible v [-0.00968 -0.98142] v_opt [-0.00968 -0.98142]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Agent 5 v_pref 0 feasible v [-1.       0.00062] v_opt [-1.       0.00062]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 v_pref 0 feasible v [-0.16775  0.65652] v_opt [-0.16775  0.65652]
# Parent agent 6  calling PIBT for agent 7 in recursive call
# Agent 7 v_pref 0 feasible v [-0.00015  0.61489] v_opt [-0.00015  0.61489]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# infeasible
# Agent 7 v_pref 1 feasible v [ 0.95008 -0.31198] v_opt [ 0.95008 -0.31198]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 v_pref 0 feasible v [ 0.69036 -0.03697] v_opt [ 0.69036 -0.03697]
# Parent agent 8  calling PIBT for agent 9 in recursive call
# Agent 9 v_pref 0 feasible v [-0.75302 -0.04266] v_opt [-0.75302 -0.04266]
# Parent agent 9  calling PIBT for agent 10 in recursive call
# infeasible
# Agent 9 v_pref 1 feasible v [0.71774 0.69631] v_opt [0.71774 0.69631]
# Parent agent 9  calling PIBT for agent 10 in recursive call
# Agent 10 v_pref 0 feasible v [ 0.92858 -0.2487 ] v_opt [ 0.92858 -0.2487 ]
# Agent 0 Valid True  in outer loop
# PIBT for agent 11 in outer loop
# Agent 11 v_pref 0 feasible v [-0.99999  0.0038 ] v_opt [-0.99999  0.0038 ]
# Parent agent 11  calling PIBT for agent 12 in recursive call
# Agent 12 v_pref 0 feasible v [-0.47838  0.06922] v_opt [-0.47838  0.06922]
# Parent agent 12  calling PIBT for agent 13 in recursive call
# Agent 13 v_pref 0 feasible v [-0.47387 -0.03189] v_opt [-0.47387 -0.03189]
# Parent agent 13  calling PIBT for agent 14 in recursive call
# Agent 14 v_pref 0 feasible v [-0.51084  0.01363] v_opt [-0.51084  0.01363]
# Parent agent 14  calling PIBT for agent 15 in recursive call
# Agent 15 v_pref 0 feasible v [-0.28129 -0.06651] v_opt [-0.28129 -0.06651]
# Parent agent 15  calling PIBT for agent 16 in recursive call
# Agent 16 v_pref 0 feasible v [-0.35453  0.63643] v_opt [-0.35453  0.63643]
# ...
# Parent agent 36  calling PIBT for agent 37 in recursive call
# Agent 37 v_pref 0 feasible v [ 0.      -0.34593] v_opt [ 0.      -0.34593]
# Parent agent 37  calling PIBT for agent 39 in recursive call
# Agent 39 v_pref 0 feasible v [0.01042 0.66878] v_opt [0.01042 0.66878]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49502 -0.10613] v_opt [-0.49502 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50495  0.14387] v_opt [-0.50495  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 39 v_pref 1 feasible v [ 0.01042 -0.72442] v_opt [ 0.01042 -0.72442]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49503 -0.10613] v_opt [-0.49503 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50496  0.14387] v_opt [-0.50496  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 39 v_pref 2 feasible v [-0.97204 -0.23478] v_opt [-0.97204 -0.23478]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49503 -0.10613] v_opt [-0.49503 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50495  0.14387] v_opt [-0.50495  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 39 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49503 -0.10613] v_opt [-0.49503 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50495  0.14387] v_opt [-0.50495  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 37 v_pref 1 feasible v [ 0.      -0.58249] v_opt [ 0.      -0.58249]
# Parent agent 37  calling PIBT for agent 39 in recursive call
# Agent 39 v_pref 0 feasible v [0.01042 0.66878] v_opt [0.01042 0.66878]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49502 -0.10613] v_opt [-0.49502 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50495  0.14387] v_opt [-0.50495  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 39 v_pref 1 feasible v [ 0.01042 -0.72443] v_opt [ 0.01042 -0.72443]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49503 -0.10613] v_opt [-0.49503 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50496  0.14387] v_opt [-0.50496  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 39 v_pref 2 feasible v [-0.97204 -0.23478] v_opt [-0.97204 -0.23478]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49503 -0.10613] v_opt [-0.49503 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50495  0.14387] v_opt [-0.50495  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 39 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49503 -0.10613] v_opt [-0.49503 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50495  0.14387] v_opt [-0.50495  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 37 v_pref 2 feasible v [-0.91087 -0.41269] v_opt [-0.91087 -0.41269]
# Parent agent 37  calling PIBT for agent 39 in recursive call
# Agent 39 v_pref 0 feasible v [0.01042 0.66878] v_opt [0.01042 0.66878]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49502 -0.10613] v_opt [-0.49502 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50495  0.14387] v_opt [-0.50495  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 39 v_pref 1 feasible v [ 0.01042 -0.72442] v_opt [ 0.01042 -0.72442]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49503 -0.10613] v_opt [-0.49503 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50496  0.14387] v_opt [-0.50496  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 39 v_pref 2 feasible v [-0.97204 -0.23478] v_opt [-0.97204 -0.23478]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49503 -0.10613] v_opt [-0.49503 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50495  0.14387] v_opt [-0.50495  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 39 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49503 -0.10613] v_opt [-0.49503 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50495  0.14387] v_opt [-0.50495  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 37 v_pref 3 feasible v [-0.      -0.34593] v_opt [-0.      -0.34593]
# Parent agent 37  calling PIBT for agent 39 in recursive call
# Agent 39 v_pref 0 feasible v [0.01042 0.66878] v_opt [0.01042 0.66878]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49502 -0.10613] v_opt [-0.49502 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50495  0.14387] v_opt [-0.50495  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 39 v_pref 1 feasible v [ 0.01042 -0.72442] v_opt [ 0.01042 -0.72442]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49503 -0.10613] v_opt [-0.49503 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50496  0.14387] v_opt [-0.50496  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 39 v_pref 2 feasible v [-0.97204 -0.23478] v_opt [-0.97204 -0.23478]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49503 -0.10613] v_opt [-0.49503 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50495  0.14387] v_opt [-0.50495  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 39 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 1 feasible v [-0.49503 -0.10613] v_opt [-0.49503 -0.10613]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 2 feasible v [-0.50495  0.14387] v_opt [-0.50495  0.14387]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 33 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# infeasible
# Agent 36 v_pref 3 feasible v [0 0] v_opt [0 0]
# Parent agent 36  calling PIBT for agent 37 in recursive call
# Agent 37 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Parent agent 37  calling PIBT for agent 39 in recursive call
# Agent 39 v_pref 0 feasible v [0.01042 0.66878] v_opt [0.01042 0.66878]
# Parent agent 39  calling PIBT for agent 33 in recursive call
# Agent 33 v_pref 0 feasible v [0.99998 0.00573] v_opt [0.99998 0.00573]
# Parent agent 33  calling PIBT for agent 38 in recursive call
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[118], line 109
#     107     if orcas[a].v is None:
#     108         print("PIBT for agent",a,"in outer loop")
# --> 109         valid = PIBT(a)
#     110         print('Agent',a,'Valid',valid," in outer loop")
#     112 # We assume agent a is ranked a among the agents when dealing with conflicts.
#     113
#     114 # Execute the safe velocity.
#
# Cell In[118], line 82, in PIBT(a)
#      80 if orcas[c].v is None:
#      81     print("Parent agent",a," calling PIBT for agent",c,"in recursive call")
# ---> 82     children_valid = PIBT(c)
#      83     if not children_valid:
#      84         break
#
# Cell In[118], line 82, in PIBT(a)
#      80 if orcas[c].v is None:
#      81     print("Parent agent",a," calling PIBT for agent",c,"in recursive call")
# ---> 82     children_valid = PIBT(c)
#      83     if not children_valid:
#      84         break
#
#     [... skipping similar frames: PIBT at line 82 (6 times)]
#
# Cell In[118], line 82, in PIBT(a)
#      80 if orcas[c].v is None:
#      81     print("Parent agent",a," calling PIBT for agent",c,"in recursive call")
# ---> 82     children_valid = PIBT(c)
#      83     if not children_valid:
#      84         break
#
# Cell In[118], line 71, in PIBT(a)
#      68 candidate_v_pref.append(np.array([0,0])) # Always have zero velocity as a default
#      70 for i,v_pref in enumerate(candidate_v_pref):
# ---> 71     orcas[a].update_v(v_pref,env.obstacles,[orcas[b] for b in P])
#      72     if orcas[a].v is None:
#      73         # print("Agent",a,"infeasible")
#      74         return False
#
# File ~/Dropbox (Harvard University)/Tianpeng's research/Tianpeng & Lina/Multiagent Motion Planning/PA-Nav/notebooks_playground/../panav/ORCA.py:193, in Ordered_Agent.update_v(self, v_pref, obstacles, neigbor_agents, right_hand_rule)
#     191 def update_v(self,v_pref,obstacles,neigbor_agents,right_hand_rule=True):
#     192     self.v_opt = v_pref
# --> 193     self.v = self.safe_v(v_pref,obstacles,neigbor_agents,
#     194                             right_hand_rule=right_hand_rule)
#     195     self.v_opt = self.v
#
# File ~/Dropbox (Harvard University)/Tianpeng's research/Tianpeng & Lina/Multiagent Motion Planning/PA-Nav/notebooks_playground/../panav/ORCA.py:200, in Ordered_Agent.safe_v(self, v_pref, obstacles, higher_ranked_agents, right_hand_rule)
#     197 def safe_v(self, v_pref, obstacles, higher_ranked_agents, right_hand_rule=True):
#     198
#     199     # Constraints induced by other agents.
# --> 200     vecs = self.neighbor_constraints(higher_ranked_agents)
#     201     if vecs is None:
#     202         return None # This case corresponds to the meteorite crash: no escape from one of the neighboring agents.
#
# File ~/Dropbox (Harvard University)/Tianpeng's research/Tianpeng & Lina/Multiagent Motion Planning/PA-Nav/notebooks_playground/../panav/ORCA.py:70, in ORCA_Agent.neighbor_constraints(self, neigbor_agents)
#      66 v_rel = self.v_opt-b.v_opt
#      68 zone_code = vo.zones(v_rel)
# ---> 70 u = vo.u(v_rel)
#      73 # print("neighbor agent v_opt",b.v_opt,'zone',zone_code)
#      75 if zone_code == 2:
#
# File ~/Dropbox (Harvard University)/Tianpeng's research/Tianpeng & Lina/Multiagent Motion Planning/PA-Nav/notebooks_playground/../panav/ORCA.py:377, in VO.u(self, test_pt)
#     374 else:
#     375     to_center = test_pt - self.center
# --> 377     if la.norm(to_center)==0:
#     378         u = - self.center/(la.norm(self.center)) * self.r
#     379         print('Closely hit')
#
# File <__array_function__ internals>:180, in norm(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/PA-Nav/lib/python3.11/site-packages/numpy/linalg/linalg.py:2527, in norm(x, ord, axis, keepdims)
#    2525 else:
#    2526     sqnorm = x.dot(x)
# -> 2527 ret = sqrt(sqnorm)
#    2528 if keepdims:
#    2529     ret = ret.reshape(ndim*[1])
#
# KeyboardInterrupt:

# %%
from panav.viz import animation
from IPython.display import HTML, display
pos = np.array(pos)

dt = exec_tau

pos_to_ani = [pos[:,a,:].T for a in agents]
anim = animation(env, pos_to_ani, bloating_r, dt = dt)
display(HTML(anim.to_jshtml()))
plt.close()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgec4caf54a72348ae89fe1761a2043a1c">
#   <div class="anim-controls">
#     <input id="_anim_sliderec4caf54a72348ae89fe1761a2043a1c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animec4caf54a72348ae89fe1761a2043a1c.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animec4caf54a72348ae89fe1761a2043a1c.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animec4caf54a72348ae89fe1761a2043a1c.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animec4caf54a72348ae89fe1761a2043a1c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animec4caf54a72348ae89fe1761a2043a1c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animec4caf54a72348ae89fe1761a2043a1c.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animec4caf54a72348ae89fe1761a2043a1c.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animec4caf54a72348ae89fe1761a2043a1c.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animec4caf54a72348ae89fe1761a2043a1c.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animec4caf54a72348ae89fe1761a2043a1c.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectec4caf54a72348ae89fe1761a2043a1c"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_ec4caf54a72348ae89fe1761a2043a1c"
#              >
#       <label for="_anim_radio1_ec4caf54a72348ae89fe1761a2043a1c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_ec4caf54a72348ae89fe1761a2043a1c"
#              checked>
#       <label for="_anim_radio2_ec4caf54a72348ae89fe1761a2043a1c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_ec4caf54a72348ae89fe1761a2043a1c"
#              >
#       <label for="_anim_radio3_ec4caf54a72348ae89fe1761a2043a1c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgec4caf54a72348ae89fe1761a2043a1c";
#     var slider_id = "_anim_sliderec4caf54a72348ae89fe1761a2043a1c";
#     var loop_select_id = "_anim_loop_selectec4caf54a72348ae89fe1761a2043a1c";
#     var frames = new Array(53);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABOTUlEQ

# %% [markdown]
# # Development: Integrate PIBT Deadlock Resolution in RCA

# %%
import sys
sys.path.append('../')

sys.path.append('../../')
import numpy as np
import cvxpy as cp
from matplotlib import pyplot as plt
from panav.environment.env import MultiTunnelEnv
from panav.hybrid import HybridGraph

from panav.viz import draw_env

import shapely

from panav.ORCA import Ordered_Agent

# %load_ext autoreload
# %autoreload 2

# %load_ext snakeviz
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bloating_r = 0.5
vmax = 1.0

N = 9


results = []

env_name = "MultiTunnel"


env = MultiTunnelEnv(n_tunnel = 2, tunnel_width = bloating_r*2.5, N_agent = N)
HG = HybridGraph(env,bloating_r)

# For development purposes, force the soft edge weights to be zero, so that the agents strictly don't have head on collisions.

for e in HG.edges:
    if HG.edges[e]['type']=='soft':
        HG.edges[e]['weight'] = 0

# %%
from panav.TrafficAwarePlanning import traffic_aware_HG_plan
paths = traffic_aware_HG_plan(HG)

ref_plan = [np.array([HG.node_loc(u) for u in path]).T for path in paths]

# %%
paths
# Out:
# [[4, 1, 0, 13],
#  [5, 1, 0, 14],
#  [6, 1, 0, 15],
#  [7, 1, 0, 16],
#  [8, 2, 3, 17],
#  [9, 2, 3, 18],
#  [10, 2, 3, 19],
#  [11, 2, 3, 20],
#  [12, 2, 3, 21]]

# %%
plans = ref_plan

tau = 1 # The safe time interval. Can be generously long.
exec_tau = 1.0 * tau 
agents = np.arange(N)
start_locs = env.starts
goal_locs = env.goals
# The execution time of ORCA velocity.
# Should be much shorter than the safe interval tau.

pos = []

v_prefs = [np.zeros(start_locs[0].shape) for a in agents]

protocol = 0

orcas = [Ordered_Agent(protocol,tau,bloating_r,vmax,p,init_v = None) 
         for p in start_locs]

# We will assume agent i is ranked i among the agents when dealing with conflicts.

curr_wp_index = [0 for a in agents]

def calc_pref(agent):

    wp = plans[agent][:,curr_wp_index[agent]]
    # See if the agent has reached the current waypoint.
    if np.linalg.norm(wp-orcas[agent].p)<= bloating_r:  
        curr_wp_index[agent] = \
        np.min([curr_wp_index[agent]+1,   
                plans[agent].shape[1]-1
                                ])
        
        wp = plans[agent][:,curr_wp_index[agent]]
        
    to_wp = wp-orcas[agent].p
    
    v_prefs[agent] = to_wp/tau if tau*vmax > np.linalg.norm(to_wp) else vmax *  to_wp/(np.linalg.norm(to_wp)+1e-5)

def PIBT(a):

    P = []
    C = []

    for nb in range(len(orcas)):
        # Find all agents in the that could collide with a in the next tau seconds.
        if nb!=a and np.linalg.norm(orcas[nb].p-orcas[a].p)<orcas[nb].bloating_r+orcas[a].bloating_r\
                                                  + 2 * vmax * tau:
            if np.linalg.norm(orcas[nb].p-orcas[a].p)<orcas[nb].bloating_r+orcas[a].bloating_r:
                print("Collision! Agents ",nb,a)
            if orcas[nb].v is None:
                C.append(nb)
            else:
                P.append(nb)
            

    print("Agent",a,"P",P,"C",C)

    candidate_v_pref = []

    for theta in np.pi * np.array([0,1/2,1,3/2]):
            # Rotate v_pref clockwise by theta.
            v_right = np.array([[np.cos(-theta),-np.sin(-theta)],
                                [np.sin(-theta),np.cos(-theta)]]).dot(v_prefs[a])
            candidate_v_pref.append(v_right)
    
    for i,v_pref in enumerate(candidate_v_pref):
        orcas[a].update_v(v_pref,env.obstacles,[orcas[b] for b in P]) 
        if orcas[a].v is None:
            print("Agent",a,"infeasible")
            return False
        
        print("Agent",a,"v_pref",i,"feasible",'v',orcas[a].v,'v_opt',orcas[a].v_opt)
        
        children_valid = True
        for c in C:
            if orcas[c].v is None:
                print("Parent agent",a," calling PIBT for agent",c,"in recursive call")
                children_valid = PIBT(c)
                if not children_valid:
                    break
        
        if children_valid:
            return True

    orcas[a].v = None
    return False

for _ in range(200):
    print("################### Time step {} ################".format(_))
    pos.append(np.array([a.p for a in orcas]))
       
    for a in agents:
        # print("Agent",a)

        # Compute the preferred velocity.
        calc_pref(a)  
        
        # Reset all agent's v to be None
        orcas[a].v = None
    
    for a in agents:
        if orcas[a].v is None:
            print("PIBT for agent",a,"in outer loop")
            valid = PIBT(a)
            print('Agent',a,'Valid',valid)
    
    # We assume agent a is ranked a among the agents when dealing with conflicts.
    
    # Execute the safe velocity.
    all_reached = True
    
    for a in agents:
        dist2goal = np.linalg.norm(orcas[a].p - goal_locs[a])
        # print(a,dist2goal)

        if dist2goal>=1*bloating_r:
            orcas[a].p += orcas[a].v*exec_tau
            all_reached = False
    if all_reached:
        break
# Out:
# ################### Time step 0 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C []
# Agent 0 v_pref 0 feasible v [-0.69989 -0.71425] v_opt [-0.69989 -0.71425]
# Agent 0 Valid True
# PIBT for agent 1 in outer loop
# Agent 1 P [] C []
# Agent 1 v_pref 0 feasible v [-0.98052  0.19639] v_opt [-0.98052  0.19639]
# Agent 1 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [-0.57549  0.81781] v_opt [-0.57549  0.81781]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.35401  0.93524] v_opt [-0.35401  0.93524]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [ 0.35401 -0.93524] v_opt [ 0.35401 -0.93524]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C []
# Agent 5 v_pref 0 feasible v [ 0.50125 -0.8653 ] v_opt [ 0.50125 -0.8653 ]
# Agent 5 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [ 0.7768  -0.62974] v_opt [ 0.7768  -0.62974]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C []
# Agent 7 v_pref 0 feasible v [0.99454 0.10434] v_opt [0.99454 0.10434]
# Agent 7 Valid True
# PIBT for agent 8 in outer loop
# Agent 8 P [] C []
# Agent 8 v_pref 0 feasible v [0.69989 0.71425] v_opt [0.69989 0.71425]
# Agent 8 Valid True
# ################### Time step 1 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C []
# Agent 0 v_pref 0 feasible v [-0.69989 -0.71424] v_opt [-0.69989 -0.71424]
# Agent 0 Valid True
# PIBT for agent 1 in outer loop
# Agent 1 P [] C []
# Agent 1 v_pref 0 feasible v [-0.98052  0.19639] v_opt [-0.98052  0.19639]
# Agent 1 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [-0.57549  0.81781] v_opt [-0.57549  0.81781]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.35401  0.93524] v_opt [-0.35401  0.93524]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [ 0.35401 -0.93524] v_opt [ 0.35401 -0.93524]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C []
# Agent 5 v_pref 0 feasible v [ 0.50125 -0.8653 ] v_opt [ 0.50125 -0.8653 ]
# Agent 5 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [ 0.7768  -0.62974] v_opt [ 0.7768  -0.62974]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C []
# Agent 7 v_pref 0 feasible v [0.99454 0.10434] v_opt [0.99454 0.10434]
# Agent 7 Valid True
# PIBT for agent 8 in outer loop
# Agent 8 P [] C []
# Agent 8 v_pref 0 feasible v [0.69989 0.71424] v_opt [0.69989 0.71424]
# Agent 8 Valid True
# ################### Time step 2 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C []
# Agent 0 v_pref 0 feasible v [-0.69989 -0.71424] v_opt [-0.69989 -0.71424]
# Agent 0 Valid True
# PIBT for agent 1 in outer loop
# Agent 1 P [] C []
# Agent 1 v_pref 0 feasible v [-0.98052  0.19639] v_opt [-0.98052  0.19639]
# Agent 1 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [-0.57549  0.81781] v_opt [-0.57549  0.81781]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.35401  0.93524] v_opt [-0.35401  0.93524]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [ 0.35401 -0.93524] v_opt [ 0.35401 -0.93524]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C []
# Agent 5 v_pref 0 feasible v [ 0.50125 -0.8653 ] v_opt [ 0.50125 -0.8653 ]
# Agent 5 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C [7]
# Agent 6 v_pref 0 feasible v [ 0.7768  -0.62974] v_opt [ 0.7768  -0.62974]
# Parent agent 6  calling PIBT for agent 7 in recursive call
# Agent 7 P [6] C [8]
# Agent 7 v_pref 0 feasible v [0.99454 0.10434] v_opt [0.99454 0.10434]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 P [7] C []
# Agent 8 v_pref 0 feasible v [0.69989 0.71424] v_opt [0.69989 0.71424]
# Agent 6 Valid True
# ################### Time step 3 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C [1]
# Agent 0 v_pref 0 feasible v [-0.69989 -0.71424] v_opt [-0.69989 -0.71424]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 P [0] C []
# Agent 1 v_pref 0 feasible v [-0.98052  0.19638] v_opt [-0.98052  0.19638]
# Agent 0 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [-0.57549  0.81781] v_opt [-0.57549  0.81781]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.35401  0.93524] v_opt [-0.35401  0.93524]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [ 0.35401 -0.93524] v_opt [ 0.35401 -0.93524]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C []
# Agent 5 v_pref 0 feasible v [ 0.50125 -0.8653 ] v_opt [ 0.50125 -0.8653 ]
# Agent 5 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C [7]
# Agent 6 v_pref 0 feasible v [ 0.7768  -0.62974] v_opt [ 0.7768  -0.62974]
# Parent agent 6  calling PIBT for agent 7 in recursive call
# Agent 7 P [6] C [8]
# Agent 7 v_pref 0 feasible v [0.99453 0.10434] v_opt [0.99453 0.10434]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 P [7] C []
# Agent 8 v_pref 0 feasible v [0.69989 0.71424] v_opt [0.69989 0.71424]
# Agent 6 Valid True
# ################### Time step 4 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C [1]
# Agent 0 v_pref 0 feasible v [-0.69989 -0.71424] v_opt [-0.69989 -0.71424]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 P [0] C []
# Agent 1 v_pref 0 feasible v [-0.50974  0.12651] v_opt [-0.50974  0.12651]
# Agent 0 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [-0.57549  0.81781] v_opt [-0.57549  0.81781]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.35401  0.93524] v_opt [-0.35401  0.93524]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [ 0.35401 -0.93524] v_opt [ 0.35401 -0.93524]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C []
# Agent 5 v_pref 0 feasible v [ 0.50125 -0.8653 ] v_opt [ 0.50125 -0.8653 ]
# Agent 5 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C [7, 8]
# Agent 6 v_pref 0 feasible v [ 0.7768  -0.62974] v_opt [ 0.7768  -0.62974]
# Parent agent 6  calling PIBT for agent 7 in recursive call
# Agent 7 P [6] C [8]
# infeasible
# Agent 7 infeasible
# Agent 6 v_pref 1 feasible v [-0.62974 -0.7768 ] v_opt [-0.62974 -0.7768 ]
# Parent agent 6  calling PIBT for agent 7 in recursive call
# Agent 7 P [6] C [8]
# Agent 7 v_pref 0 feasible v [0.48861 0.05681] v_opt [0.48861 0.05681]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 P [6, 7] C []
# Agent 8 v_pref 0 feasible v [0.69989 0.71424] v_opt [0.69989 0.71424]
# Agent 6 Valid True
# ################### Time step 5 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C [1]
# Agent 0 v_pref 0 feasible v [-0.50054 -0.71424] v_opt [-0.50054 -0.71424]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 P [0] C [2]
# Agent 1 v_pref 0 feasible v [-0.99811 -0.02322] v_opt [-0.99811 -0.02322]
# Parent agent 1  calling PIBT for agent 2 in recursive call
# Agent 2 P [1] C []
# Agent 2 v_pref 0 feasible v [-0.57548  0.81781] v_opt [-0.57548  0.81781]
# Agent 0 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.35401  0.93524] v_opt [-0.35401  0.93524]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [ 0.35401 -0.93524] v_opt [ 0.35401 -0.93524]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C [6]
# Agent 5 v_pref 0 feasible v [ 0.50125 -0.8653 ] v_opt [ 0.50125 -0.8653 ]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5] C [7, 8]
# Agent 6 v_pref 0 feasible v [ 0.99165 -0.12894] v_opt [ 0.99165 -0.12894]
# Parent agent 6  calling PIBT for agent 7 in recursive call
# Agent 7 P [6] C [8]
# Agent 7 v_pref 0 feasible v [ 0.99999 -0.00306] v_opt [ 0.99999 -0.00306]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 P [6, 7] C []
# Agent 8 v_pref 0 feasible v [ 0.50054 -0.36903] v_opt [ 0.50054 -0.36903]
# Agent 5 Valid True
# ################### Time step 6 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C [1, 2]
# Agent 0 v_pref 0 feasible v [-0.45062 -0.23875] v_opt [-0.45062 -0.23875]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 P [0] C [2]
# Agent 1 v_pref 0 feasible v [-0.99999 -0.00329] v_opt [-0.99999 -0.00329]
# Parent agent 1  calling PIBT for agent 2 in recursive call
# Agent 2 P [0, 1] C []
# Agent 2 v_pref 0 feasible v [-0.28688  0.53224] v_opt [-0.28688  0.53224]
# Agent 0 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.35401  0.93524] v_opt [-0.35401  0.93524]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [ 0.35401 -0.93524] v_opt [ 0.35401 -0.93524]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C [6]
# Agent 5 v_pref 0 feasible v [ 0.50125 -0.8653 ] v_opt [ 0.50125 -0.8653 ]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5] C [7, 8]
# Agent 6 v_pref 0 feasible v [ 0.80456 -0.16382] v_opt [ 0.80456 -0.16382]
# Parent agent 6  calling PIBT for agent 7 in recursive call
# Agent 7 P [6] C [8]
# Agent 7 v_pref 0 feasible v [ 0.99999 -0.00306] v_opt [ 0.99999 -0.00306]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 P [6, 7] C []
# Agent 8 v_pref 0 feasible v [-0.       0.20002] v_opt [-0.       0.20002]
# Agent 5 Valid True
# ################### Time step 7 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C [1, 2]
# Agent 0 v_pref 0 feasible v [-0.99869  0.02666] v_opt [-0.99869  0.02666]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 P [0] C [2]
# Agent 1 v_pref 0 feasible v [-0.99999 -0.00329] v_opt [-0.99999 -0.00329]
# Parent agent 1  calling PIBT for agent 2 in recursive call
# Agent 2 P [0, 1] C []
# Agent 2 v_pref 0 feasible v [-0.26021  0.76924] v_opt [-0.26021  0.76924]
# Agent 0 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.35401  0.93524] v_opt [-0.35401  0.93524]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [ 0.35401 -0.93524] v_opt [ 0.35401 -0.93524]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C [6, 8]
# Agent 5 v_pref 0 feasible v [ 0.49124 -0.8653 ] v_opt [ 0.49124 -0.8653 ]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5] C [7, 8]
# infeasible
# Agent 6 infeasible
# Agent 5 v_pref 1 feasible v [-0.8653  -0.50125] v_opt [-0.8653  -0.50125]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5] C [7, 8]
# Agent 6 v_pref 0 feasible v [0.48094 0.05847] v_opt [0.48094 0.05847]
# Parent agent 6  calling PIBT for agent 7 in recursive call
# Agent 7 P [6] C [8]
# Agent 7 v_pref 0 feasible v [ 0.99999 -0.00306] v_opt [ 0.99999 -0.00306]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 P [5, 6, 7] C []
# Agent 8 v_pref 0 feasible v [-0.02664  0.37782] v_opt [-0.02664  0.37782]
# Agent 5 Valid True
# ################### Time step 8 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C [1, 2]
# Agent 0 v_pref 0 feasible v [-0.99995  0.00938] v_opt [-0.99995  0.00938]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 P [0] C []
# Agent 1 v_pref 0 feasible v [-0.99999 -0.00329] v_opt [-0.99999 -0.00329]
# Parent agent 0  calling PIBT for agent 2 in recursive call
# Agent 2 P [0] C []
# Agent 2 v_pref 0 feasible v [-0.48086  0.00001] v_opt [-0.48086  0.00001]
# Agent 0 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.35401  0.93524] v_opt [-0.35401  0.93524]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [ 0.35401 -0.93524] v_opt [ 0.35401 -0.93524]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C [6, 8]
# Agent 5 v_pref 0 feasible v [ 0.86879 -0.49517] v_opt [ 0.86879 -0.49517]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5] C [7, 8]
# Agent 6 v_pref 0 feasible v [ 1.      -0.00238] v_opt [ 1.      -0.00238]
# Parent agent 6  calling PIBT for agent 7 in recursive call
# Agent 7 P [6] C []
# Agent 7 v_pref 0 feasible v [ 0.99999 -0.00306] v_opt [ 0.99999 -0.00306]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Agent 8 P [5, 6] C []
# Agent 8 v_pref 0 feasible v [0.02664 0.67831] v_opt [0.02664 0.67831]
# Agent 5 Valid True
# ################### Time step 9 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C [1, 2]
# Agent 0 v_pref 0 feasible v [-0.99995  0.00938] v_opt [-0.99995  0.00938]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 P [0] C []
# Agent 1 v_pref 0 feasible v [-0.99999 -0.00329] v_opt [-0.99999 -0.00329]
# Parent agent 0  calling PIBT for agent 2 in recursive call
# Agent 2 P [0] C []
# Agent 2 v_pref 0 feasible v [-1. -0.] v_opt [-1. -0.]
# Agent 0 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.35401  0.93524] v_opt [-0.35401  0.93524]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C [5]
# Agent 4 v_pref 0 feasible v [ 0.35401 -0.93524] v_opt [ 0.35401 -0.93524]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Collision! Agents  8 5
# Agent 5 P [4] C [6, 8]
# Agent 5 v_pref 0 feasible v [ 0.57496 -0.52716] v_opt [ 0.57496 -0.52716]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5] C [7, 8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 7 in recursive call
# Agent 7 P [6] C []
# Agent 7 v_pref 0 feasible v [ 0.99999 -0.00306] v_opt [ 0.99999 -0.00306]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 1 feasible v [-0.48816 -0.85649] v_opt [-0.48816 -0.85649]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 2 feasible v [-0.85649  0.48816] v_opt [-0.85649  0.48816]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 3 feasible v [0.38524 0.84223] v_opt [0.38524 0.84223]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 4 v_pref 1 feasible v [-0.93524 -0.35401] v_opt [-0.93524 -0.35401]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Collision! Agents  8 5
# Agent 5 P [4] C [6, 8]
# Agent 5 v_pref 0 feasible v [ 0.57496 -0.52716] v_opt [ 0.57496 -0.52716]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 1 feasible v [-0.48816 -0.85649] v_opt [-0.48816 -0.85649]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 2 feasible v [-0.85649  0.48816] v_opt [-0.85649  0.48816]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 3 feasible v [0.38524 0.84223] v_opt [0.38524 0.84223]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 4 v_pref 2 feasible v [-0.35401  0.93524] v_opt [-0.35401  0.93524]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Collision! Agents  8 5
# Agent 5 P [4] C [6, 8]
# Agent 5 v_pref 0 feasible v [ 0.57496 -0.52716] v_opt [ 0.57496 -0.52716]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 1 feasible v [-0.48816 -0.85649] v_opt [-0.48816 -0.85649]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 2 feasible v [-0.85649  0.48816] v_opt [-0.85649  0.48816]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 3 feasible v [0.38524 0.84223] v_opt [0.38524 0.84223]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 4 v_pref 3 feasible v [0.81393 0.35401] v_opt [0.81393 0.35401]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Collision! Agents  8 5
# Agent 5 P [4] C [6, 8]
# Agent 5 v_pref 0 feasible v [ 0.57496 -0.52716] v_opt [ 0.57496 -0.52716]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 1 feasible v [-0.48816 -0.85649] v_opt [-0.48816 -0.85649]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 2 feasible v [-0.85649  0.48816] v_opt [-0.85649  0.48816]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 3 feasible v [0.38524 0.84223] v_opt [0.38524 0.84223]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 4 Valid False
# PIBT for agent 5 in outer loop
# Collision! Agents  8 5
# Agent 5 P [] C [4, 6, 8]
# Agent 5 v_pref 0 feasible v [ 0.57496 -0.52716] v_opt [ 0.57496 -0.52716]
# Parent agent 5  calling PIBT for agent 4 in recursive call
# Agent 4 P [5] C []
# Agent 4 v_pref 0 feasible v [ 0.35401 -0.93524] v_opt [ 0.35401 -0.93524]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 1 feasible v [-0.48816 -0.85649] v_opt [-0.48816 -0.85649]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 2 feasible v [-0.85649  0.48816] v_opt [-0.85649  0.48816]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 3 feasible v [0.38524 0.84223] v_opt [0.38524 0.84223]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 Valid False
# PIBT for agent 6 in outer loop
# Agent 6 P [7] C [5, 8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 5 in recursive call
# Collision! Agents  8 5
# Agent 5 P [4, 6] C [8]
# Agent 5 v_pref 0 feasible v [ 0.57496 -0.52716] v_opt [ 0.57496 -0.52716]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 1 feasible v [-0.48816 -0.85649] v_opt [-0.48816 -0.85649]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 2 feasible v [-0.85649  0.48816] v_opt [-0.85649  0.48816]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 3 feasible v [0.38524 0.84223] v_opt [0.38524 0.84223]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13424] v_opt [-0.00238 -0.13424]
# Parent agent 6  calling PIBT for agent 5 in recursive call
# Collision! Agents  8 5
# Agent 5 P [4, 6] C [8]
# Agent 5 v_pref 0 feasible v [ 0.57496 -0.52716] v_opt [ 0.57496 -0.52716]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 1 feasible v [-0.48816 -0.85649] v_opt [-0.48816 -0.85649]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 2 feasible v [-0.85649  0.48816] v_opt [-0.85649  0.48816]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 3 feasible v [0.38524 0.84223] v_opt [0.38524 0.84223]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 5 in recursive call
# Collision! Agents  8 5
# Agent 5 P [4, 6] C [8]
# Agent 5 v_pref 0 feasible v [ 0.57496 -0.52716] v_opt [ 0.57496 -0.52716]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 1 feasible v [-0.48816 -0.85649] v_opt [-0.48816 -0.85649]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 2 feasible v [-0.85649  0.48816] v_opt [-0.85649  0.48816]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 3 feasible v [0.38524 0.84223] v_opt [0.38524 0.84223]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11576] v_opt [0.00238 0.11576]
# Parent agent 6  calling PIBT for agent 5 in recursive call
# Collision! Agents  8 5
# Agent 5 P [4, 6] C [8]
# Agent 5 v_pref 0 feasible v [ 0.57496 -0.52716] v_opt [ 0.57496 -0.52716]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 1 feasible v [-0.48816 -0.85649] v_opt [-0.48816 -0.85649]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 2 feasible v [-0.85649  0.48816] v_opt [-0.85649  0.48816]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 3 feasible v [0.38524 0.84223] v_opt [0.38524 0.84223]
# Parent agent 5  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 Valid False
# PIBT for agent 8 in outer loop
# Collision! Agents  5 8
# Agent 8 P [] C [5, 6]
# Agent 8 v_pref 0 feasible v [ 0.48086 -0.00001] v_opt [ 0.48086 -0.00001]
# Parent agent 8  calling PIBT for agent 5 in recursive call
# Collision! Agents  8 5
# Agent 5 P [4, 8] C [6]
# Agent 5 v_pref 0 feasible v [ 0.36875 -0.00001] v_opt [ 0.36875 -0.00001]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7, 8] C []
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Agent 8 Valid True
# ################### Time step 10 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C [1, 2]
# Agent 0 v_pref 0 feasible v [-0.99995  0.00938] v_opt [-0.99995  0.00938]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 P [0] C []
# Agent 1 v_pref 0 feasible v [-0.7268  -0.12566] v_opt [-0.7268  -0.12566]
# Parent agent 0  calling PIBT for agent 2 in recursive call
# Agent 2 P [0] C [3]
# Agent 2 v_pref 0 feasible v [-1. -0.] v_opt [-1. -0.]
# Parent agent 2  calling PIBT for agent 3 in recursive call
# Agent 3 P [2] C []
# Agent 3 v_pref 0 feasible v [-0.35401  0.93524] v_opt [-0.35401  0.93524]
# Agent 0 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C [5, 8]
# Agent 4 v_pref 0 feasible v [ 0.35401 -0.93524] v_opt [ 0.35401 -0.93524]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Collision! Agents  8 5
# Agent 5 P [4] C [6, 8]
# Agent 5 v_pref 0 feasible v [ 0.2564 -0.5393] v_opt [ 0.2564 -0.5393]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5] C [7, 8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 7 in recursive call
# Agent 7 P [6] C []
# Agent 7 v_pref 0 feasible v [0.65479 0.1245 ] v_opt [0.65479 0.1245 ]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13185] v_opt [-0.00238 -0.13185]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11815] v_opt [0.00238 0.11815]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 1 feasible v [-0.48815 -0.48774] v_opt [-0.48815 -0.48774]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13185] v_opt [-0.00238 -0.13185]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11815] v_opt [0.00238 0.11815]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 2 feasible v [-0.80001  0.15873] v_opt [-0.80001  0.15873]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13185] v_opt [-0.00238 -0.13185]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11815] v_opt [0.00238 0.11815]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# infeasible
# Agent 5 infeasible
# Agent 4 v_pref 1 feasible v [-0.93524 -0.35401] v_opt [-0.93524 -0.35401]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Collision! Agents  8 5
# Agent 5 P [4] C [6, 8]
# Agent 5 v_pref 0 feasible v [ 0.2564 -0.5393] v_opt [ 0.2564 -0.5393]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13185] v_opt [-0.00238 -0.13185]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11815] v_opt [0.00238 0.11815]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 1 feasible v [-0.48815 -0.48774] v_opt [-0.48815 -0.48774]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13185] v_opt [-0.00238 -0.13185]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11815] v_opt [0.00238 0.11815]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 2 feasible v [-0.48774  0.48815] v_opt [-0.48774  0.48815]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13185] v_opt [-0.00238 -0.13185]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11815] v_opt [0.00238 0.11815]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 5 v_pref 3 feasible v [0.05072 0.39103] v_opt [0.05072 0.39103]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13185] v_opt [-0.00238 -0.13185]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11815] v_opt [0.00238 0.11815]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 4 v_pref 2 feasible v [-0.35401  0.93524] v_opt [-0.35401  0.93524]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Collision! Agents  8 5
# Agent 5 P [4] C [6, 8]
# Agent 5 v_pref 0 feasible v [ 0.2564 -0.5393] v_opt [ 0.2564 -0.5393]
# Parent agent 5  calling PIBT for agent 6 in recursive call
# Agent 6 P [5, 7] C [8]
# Agent 6 v_pref 0 feasible v [ 0.99999 -0.00238] v_opt [ 0.99999 -0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 1 feasible v [-0.00238 -0.13185] v_opt [-0.00238 -0.13185]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 2 feasible v [-0.99999  0.00238] v_opt [-0.99999  0.00238]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# Agent 8 P [4, 5, 6] C []
# infeasible
# Agent 8 infeasible
# Agent 6 v_pref 3 feasible v [0.00238 0.11815] v_opt [0.00238 0.11815]
# Parent agent 6  calling PIBT for agent 8 in recursive call
# Collision! Agents  5 8
# ...
# Parent agent 4  calling PIBT for agent 8 in recursive call
# Agent 8 P [4] C [6]
# Agent 8 v_pref 0 feasible v [0.45747 0.88922] v_opt [0.45747 0.88922]
# Parent agent 8  calling PIBT for agent 6 in recursive call
# Agent 6 P [8] C []
# Agent 6 v_pref 0 feasible v [0.86217 0.50661] v_opt [0.86217 0.50661]
# Agent 4 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C []
# Agent 7 v_pref 0 feasible v [0.62115 0.78369] v_opt [0.62115 0.78369]
# Agent 7 Valid True
# ################### Time step 18 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C [1]
# Agent 0 v_pref 0 feasible v [-0.45602 -0.88997] v_opt [-0.45602 -0.88997]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 P [0] C []
# Agent 1 v_pref 0 feasible v [-0.69273 -0.72119] v_opt [-0.69273 -0.72119]
# Agent 0 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [-0.99092 -0.13444] v_opt [-0.99092 -0.13444]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.60314  0.00347] v_opt [-0.60314  0.00347]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C [5, 8]
# Agent 4 v_pref 0 feasible v [ 0.60314 -0.00347] v_opt [ 0.60314 -0.00347]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Agent 5 P [4] C []
# Agent 5 v_pref 0 feasible v [0.99999 0.00197] v_opt [0.99999 0.00197]
# Parent agent 4  calling PIBT for agent 8 in recursive call
# Agent 8 P [4] C []
# Agent 8 v_pref 0 feasible v [0.45747 0.88922] v_opt [0.45747 0.88922]
# Agent 4 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [0.86217 0.50661] v_opt [0.86217 0.50661]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C []
# Agent 7 v_pref 0 feasible v [0.62115 0.78368] v_opt [0.62115 0.78368]
# Agent 7 Valid True
# ################### Time step 19 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C [1]
# Agent 0 v_pref 0 feasible v [-0.45602 -0.88997] v_opt [-0.45602 -0.88997]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 P [0] C []
# Agent 1 v_pref 0 feasible v [-0.30144 -0.31382] v_opt [-0.30144 -0.31382]
# Agent 0 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [-0.99092 -0.13444] v_opt [-0.99092 -0.13444]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.87147  0.32467] v_opt [-0.87147  0.32467]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C [5]
# Agent 4 v_pref 0 feasible v [ 0.87147 -0.32467] v_opt [ 0.87147 -0.32467]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Agent 5 P [4] C []
# Agent 5 v_pref 0 feasible v [0.99999 0.00197] v_opt [0.99999 0.00197]
# Agent 4 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [0.86217 0.5066 ] v_opt [0.86217 0.5066 ]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C []
# Agent 7 v_pref 0 feasible v [0.62115 0.78368] v_opt [0.62115 0.78368]
# Agent 7 Valid True
# PIBT for agent 8 in outer loop
# Agent 8 P [] C []
# Agent 8 v_pref 0 feasible v [0.45747 0.88922] v_opt [0.45747 0.88922]
# Agent 8 Valid True
# ################### Time step 20 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C [1]
# Agent 0 v_pref 0 feasible v [-0.45602 -0.88997] v_opt [-0.45602 -0.88997]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 P [0] C []
# Agent 1 v_pref 0 feasible v [-0.30144 -0.31382] v_opt [-0.30144 -0.31382]
# Agent 0 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [-0.57346 -0.0778 ] v_opt [-0.57346 -0.0778 ]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.79925  0.601  ] v_opt [-0.79925  0.601  ]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C [5]
# Agent 4 v_pref 0 feasible v [ 0.79925 -0.601  ] v_opt [ 0.79925 -0.601  ]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Agent 5 P [4] C []
# Agent 5 v_pref 0 feasible v [0.82778 0.00163] v_opt [0.82778 0.00163]
# Agent 4 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [0.2894  0.17005] v_opt [0.2894  0.17005]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C []
# Agent 7 v_pref 0 feasible v [0.28811 0.36349] v_opt [0.28811 0.36349]
# Agent 7 Valid True
# PIBT for agent 8 in outer loop
# Agent 8 P [] C []
# Agent 8 v_pref 0 feasible v [0.45747 0.88922] v_opt [0.45747 0.88922]
# Agent 8 Valid True
# ################### Time step 21 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C [1]
# Agent 0 v_pref 0 feasible v [-0.45602 -0.88997] v_opt [-0.45602 -0.88997]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 P [0] C []
# Agent 1 v_pref 0 feasible v [-0.30144 -0.31382] v_opt [-0.30144 -0.31382]
# Agent 0 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.79925  0.60099] v_opt [-0.79925  0.60099]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C [5]
# Agent 4 v_pref 0 feasible v [ 0.79925 -0.60099] v_opt [ 0.79925 -0.60099]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Agent 5 P [4] C []
# Agent 5 v_pref 0 feasible v [ 0.99742 -0.07178] v_opt [ 0.99742 -0.07178]
# Agent 4 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [0.2894  0.17005] v_opt [0.2894  0.17005]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C []
# Agent 7 v_pref 0 feasible v [0.28811 0.36349] v_opt [0.28811 0.36349]
# Agent 7 Valid True
# PIBT for agent 8 in outer loop
# Agent 8 P [] C []
# Agent 8 v_pref 0 feasible v [0.45747 0.88922] v_opt [0.45747 0.88922]
# Agent 8 Valid True
# ################### Time step 22 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C [1]
# Agent 0 v_pref 0 feasible v [-0.45602 -0.88997] v_opt [-0.45602 -0.88997]
# Parent agent 0  calling PIBT for agent 1 in recursive call
# Agent 1 P [0] C []
# Agent 1 v_pref 0 feasible v [-0.30144 -0.31382] v_opt [-0.30144 -0.31382]
# Agent 0 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.79925  0.60099] v_opt [-0.79925  0.60099]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C [5]
# Agent 4 v_pref 0 feasible v [ 0.79925 -0.60099] v_opt [ 0.79925 -0.60099]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Agent 5 P [4] C []
# Agent 5 v_pref 0 feasible v [ 0.99742 -0.07178] v_opt [ 0.99742 -0.07178]
# Agent 4 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [0.2894  0.17005] v_opt [0.2894  0.17005]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C []
# Agent 7 v_pref 0 feasible v [0.28811 0.36349] v_opt [0.28811 0.36349]
# Agent 7 Valid True
# PIBT for agent 8 in outer loop
# Agent 8 P [] C []
# Agent 8 v_pref 0 feasible v [0.45747 0.88922] v_opt [0.45747 0.88922]
# Agent 8 Valid True
# ################### Time step 23 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C []
# Agent 0 v_pref 0 feasible v [-0.45602 -0.88997] v_opt [-0.45602 -0.88997]
# Agent 0 Valid True
# PIBT for agent 1 in outer loop
# Agent 1 P [] C []
# Agent 1 v_pref 0 feasible v [-0.30144 -0.31382] v_opt [-0.30144 -0.31382]
# Agent 1 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.79925  0.60099] v_opt [-0.79925  0.60099]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C [5]
# Agent 4 v_pref 0 feasible v [ 0.79925 -0.60099] v_opt [ 0.79925 -0.60099]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Agent 5 P [4] C []
# Agent 5 v_pref 0 feasible v [ 0.99742 -0.07178] v_opt [ 0.99742 -0.07178]
# Agent 4 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [0.2894  0.17005] v_opt [0.2894  0.17005]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C [8]
# Agent 7 v_pref 0 feasible v [0.28811 0.36349] v_opt [0.28811 0.36349]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 P [7] C []
# Agent 8 v_pref 0 feasible v [0.45747 0.88922] v_opt [0.45747 0.88922]
# Agent 7 Valid True
# ################### Time step 24 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C []
# Agent 0 v_pref 0 feasible v [-0.45602 -0.88996] v_opt [-0.45602 -0.88996]
# Agent 0 Valid True
# PIBT for agent 1 in outer loop
# Agent 1 P [] C []
# Agent 1 v_pref 0 feasible v [-0.30144 -0.31382] v_opt [-0.30144 -0.31382]
# Agent 1 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.79925  0.60099] v_opt [-0.79925  0.60099]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C [5]
# Agent 4 v_pref 0 feasible v [ 0.79925 -0.60099] v_opt [ 0.79925 -0.60099]
# Parent agent 4  calling PIBT for agent 5 in recursive call
# Agent 5 P [4] C []
# Agent 5 v_pref 0 feasible v [ 0.99742 -0.07178] v_opt [ 0.99742 -0.07178]
# Agent 4 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [0.2894  0.17005] v_opt [0.2894  0.17005]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C [8]
# Agent 7 v_pref 0 feasible v [0.28811 0.36349] v_opt [0.28811 0.36349]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 P [7] C []
# Agent 8 v_pref 0 feasible v [0.45747 0.88922] v_opt [0.45747 0.88922]
# Agent 7 Valid True
# ################### Time step 25 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C []
# Agent 0 v_pref 0 feasible v [-0.45115 -0.88046] v_opt [-0.45115 -0.88046]
# Agent 0 Valid True
# PIBT for agent 1 in outer loop
# Agent 1 P [] C []
# Agent 1 v_pref 0 feasible v [-0.30144 -0.31382] v_opt [-0.30144 -0.31382]
# Agent 1 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.79925  0.60099] v_opt [-0.79925  0.60099]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [ 0.79925 -0.60099] v_opt [ 0.79925 -0.60099]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C []
# Agent 5 v_pref 0 feasible v [ 0.99742 -0.07178] v_opt [ 0.99742 -0.07178]
# Agent 5 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [0.2894  0.17005] v_opt [0.2894  0.17005]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C [8]
# Agent 7 v_pref 0 feasible v [0.28811 0.36349] v_opt [0.28811 0.36349]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 P [7] C []
# Agent 8 v_pref 0 feasible v [0.45747 0.88922] v_opt [0.45747 0.88922]
# Agent 7 Valid True
# ################### Time step 26 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C []
# Agent 0 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 0 Valid True
# PIBT for agent 1 in outer loop
# Agent 1 P [] C []
# Agent 1 v_pref 0 feasible v [-0.30144 -0.31382] v_opt [-0.30144 -0.31382]
# Agent 1 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [-0.70178  0.5277 ] v_opt [-0.70178  0.5277 ]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [ 0.70178 -0.5277 ] v_opt [ 0.70178 -0.5277 ]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C []
# Agent 5 v_pref 0 feasible v [ 0.99741 -0.07178] v_opt [ 0.99741 -0.07178]
# Agent 5 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [0.2894  0.17005] v_opt [0.2894  0.17005]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C [8]
# Agent 7 v_pref 0 feasible v [0.28811 0.36349] v_opt [0.28811 0.36349]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 P [7] C []
# Agent 8 v_pref 0 feasible v [0.45747 0.88922] v_opt [0.45747 0.88922]
# Agent 7 Valid True
# ################### Time step 27 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C []
# Agent 0 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 0 Valid True
# PIBT for agent 1 in outer loop
# Agent 1 P [] C []
# Agent 1 v_pref 0 feasible v [-0.30144 -0.31382] v_opt [-0.30144 -0.31382]
# Agent 1 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C []
# Agent 5 v_pref 0 feasible v [ 0.38425 -0.02765] v_opt [ 0.38425 -0.02765]
# Agent 5 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [0.2894  0.17005] v_opt [0.2894  0.17005]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C [8]
# Agent 7 v_pref 0 feasible v [0.28811 0.36349] v_opt [0.28811 0.36349]
# Parent agent 7  calling PIBT for agent 8 in recursive call
# Agent 8 P [7] C []
# Agent 8 v_pref 0 feasible v [0.45747 0.88922] v_opt [0.45747 0.88922]
# Agent 7 Valid True
# ################### Time step 28 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C []
# Agent 0 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 0 Valid True
# PIBT for agent 1 in outer loop
# Agent 1 P [] C []
# Agent 1 v_pref 0 feasible v [-0.30144 -0.31382] v_opt [-0.30144 -0.31382]
# Agent 1 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C []
# Agent 5 v_pref 0 feasible v [ 0.38425 -0.02765] v_opt [ 0.38425 -0.02765]
# Agent 5 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [0.2894  0.17005] v_opt [0.2894  0.17005]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C []
# Agent 7 v_pref 0 feasible v [0.28811 0.36349] v_opt [0.28811 0.36349]
# Agent 7 Valid True
# PIBT for agent 8 in outer loop
# Agent 8 P [] C []
# Agent 8 v_pref 0 feasible v [0.43635 0.84818] v_opt [0.43635 0.84818]
# Agent 8 Valid True
# ################### Time step 29 ################
# PIBT for agent 0 in outer loop
# Agent 0 P [] C []
# Agent 0 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 0 Valid True
# PIBT for agent 1 in outer loop
# Agent 1 P [] C []
# Agent 1 v_pref 0 feasible v [-0.30144 -0.31382] v_opt [-0.30144 -0.31382]
# Agent 1 Valid True
# PIBT for agent 2 in outer loop
# Agent 2 P [] C []
# Agent 2 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 2 Valid True
# PIBT for agent 3 in outer loop
# Agent 3 P [] C []
# Agent 3 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 3 Valid True
# PIBT for agent 4 in outer loop
# Agent 4 P [] C []
# Agent 4 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 4 Valid True
# PIBT for agent 5 in outer loop
# Agent 5 P [] C []
# Agent 5 v_pref 0 feasible v [ 0.38425 -0.02765] v_opt [ 0.38425 -0.02765]
# Agent 5 Valid True
# PIBT for agent 6 in outer loop
# Agent 6 P [] C []
# Agent 6 v_pref 0 feasible v [0.2894  0.17005] v_opt [0.2894  0.17005]
# Agent 6 Valid True
# PIBT for agent 7 in outer loop
# Agent 7 P [] C []
# Agent 7 v_pref 0 feasible v [0.28811 0.36349] v_opt [0.28811 0.36349]
# Agent 7 Valid True
# PIBT for agent 8 in outer loop
# Agent 8 P [] C []
# Agent 8 v_pref 0 feasible v [0. 0.] v_opt [0. 0.]
# Agent 8 Valid True

# %%
from panav.viz import animation
from IPython.display import HTML, display
pos = np.array(pos)

dt = exec_tau

pos_to_ani = [pos[:,a,:].T for a in agents]
anim = animation(env, pos_to_ani, bloating_r, dt = dt)
display(HTML(anim.to_jshtml()))
plt.close()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img520bdda19e0143eead4025c144c626ca">
#   <div class="anim-controls">
#     <input id="_anim_slider520bdda19e0143eead4025c144c626ca" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim520bdda19e0143eead4025c144c626ca.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim520bdda19e0143eead4025c144c626ca.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim520bdda19e0143eead4025c144c626ca.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim520bdda19e0143eead4025c144c626ca.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim520bdda19e0143eead4025c144c626ca.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim520bdda19e0143eead4025c144c626ca.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim520bdda19e0143eead4025c144c626ca.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim520bdda19e0143eead4025c144c626ca.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim520bdda19e0143eead4025c144c626ca.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim520bdda19e0143eead4025c144c626ca.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select520bdda19e0143eead4025c144c626ca"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_520bdda19e0143eead4025c144c626ca"
#              >
#       <label for="_anim_radio1_520bdda19e0143eead4025c144c626ca">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_520bdda19e0143eead4025c144c626ca"
#              checked>
#       <label for="_anim_radio2_520bdda19e0143eead4025c144c626ca">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_520bdda19e0143eead4025c144c626ca"
#              >
#       <label for="_anim_radio3_520bdda19e0143eead4025c144c626ca">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img520bdda19e0143eead4025c144c626ca";
#     var slider_id = "_anim_slider520bdda19e0143eead4025c144c626ca";
#     var loop_select_id = "_anim_loop_select520bdda19e0143eead4025c144c626ca";
#     var frames = new Array(30);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABSYElEQ

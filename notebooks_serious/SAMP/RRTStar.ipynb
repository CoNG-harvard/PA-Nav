# %%
import sys
sys.path.append('../../')
from panav.env import NavigationEnv, Box2DRegion, PolygonRegion, box_2d_center, line_seg_to_obstacle
from panav.viz import draw_env
from panav.RRT.RRT import RRT
import shapely
import numpy as np
from matplotlib import pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
start_locs = np.array([[5,5]])
goal_locs = np.array([[-5,5]])


start_box_side = np.array([1,1])
goal_box_side = np.array([1,1])

starts = [box_2d_center(s,start_box_side) for s in start_locs]

goals = [box_2d_center(g,goal_box_side) for g in goal_locs]

O1 = Box2DRegion((-2.5,2.5),(0.5,10))
O2 = Box2DRegion((-2.5,2.5),(-10,-1.0))

limits = [(-10.0,10.0),(-10.0,10.0)]

bloating_r = 0.5 

env = NavigationEnv(limits,[O1,O2],starts,goals)

draw_env(env)

# %% [markdown]
# # The RRT* algorithm(Karaman & Frazzoli 2010)

# %%
class RRT_star(RRT):
    def __init__(self,x_init):
        super().__init__(x_init)
    
    def space_neighbors(self,xq,D):
        '''
            Return the nodes in self that is within distance D to xq.
        '''
        pass
    def add_loc(self,parent,x_loc):
        '''
            Overrides the RRT class's add_loc() method, implement re-wiring operations.
        '''
        pass

# %%
ax = plt.gca()


draw_env(env,ax=ax)

ax.scatter(*start_locs[0],marker = "+",label = r'$x_{start}$')

# ax.plot(plan[:,0],plan[:,1])
# draw_rrt(ax,T)
ax.legend()
plt.show()

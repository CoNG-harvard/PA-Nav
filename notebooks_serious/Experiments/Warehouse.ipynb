# %% [markdown]
# # Benchmarking Our Algorithm against others

# %%
import sys
sys.path.append('../')
from panav.environment.env import WareHouse
from panav.hybrid import WareHouseHG
from panav.util import flowtime,makespan
from panav.PBS.PBS import PBS
from panav.TrafficAwarePlanning import TAHP
from panav.sequential import sequential_planning
from panav.PIBT import PIBT_plan
from panav.SAMP.solvers import Tube_Planning



from time import time
import pickle as pkl

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bloating_r = 0.5
vmax = 1.0

#### 100 agent configuration ####
n_agents = list(range(10,101,10))
bloating_r = 0.5
vmax = 1.0


n_col = 10
n_row = 10
limits = [(-50,50),(-50,50)] 
shelf_region_x_limit=[-30,30]
shelf_region_y_limit=[-30,30]
corner_padding_x = bloating_r * 10
corner_padding_y = bloating_r * 10
obs_x_margin = 8 * bloating_r
obs_y_margin = 8 * bloating_r

TIMEOUT = 100 # timeout

# Algorithms
algs = {  
        "PIBT": lambda hg: PIBT_plan(hg,vmax,bloating_r,TIMEOUT),
        "S2M2": lambda hg: PBS(hg.env,vmax=vmax,bloating_r=bloating_r,low_level_planner="Simple_MILP_Planning",TIMEOUT=TIMEOUT)[0],
        "PBS_Tube": lambda hg: PBS(hg.env,vmax=vmax,bloating_r=bloating_r,low_level_planner="Tube_Planning",TIMEOUT=TIMEOUT)[0],
        "TAHP": lambda hg: TAHP(hg,vmax=vmax,bloating_r=bloating_r,TIMEOUT=TIMEOUT),
        "Seq_Tube": lambda hg: sequential_planning(Tube_Planning,hg.env,vmax,bloating_r,TIMEOUT=TIMEOUT),      
        # "Seq_Temp_Obs": lambda hg: sequential_planning(Simple_MILP_Planning,hg.env,vmax,bloating_r,TIMEOUT=TIMEOUT)
        }

timeouted = {alg:False for alg in algs}

results = []

env_name = "Warehouse"

# %%
# Experiments
cur_N = 0
for i in range(len(n_agents)):
    
    N = n_agents[i]
   

    env = WareHouse(limits = limits, N_agent = N, 
                    shelf_region_x_limit=shelf_region_x_limit,shelf_region_y_limit=shelf_region_y_limit,
                    obs_x_margin = obs_x_margin,
                    obs_y_margin = obs_y_margin,
                    n_col = n_col, n_row = n_row,
                    corner_padding_x=corner_padding_x,corner_padding_y=corner_padding_y)

    print('Constructing environment')
    HG = WareHouseHG(env,bloating_r)

    if N<cur_N:
        continue
  
    # Save checkpoint data
    with open("./data/{}_misc.pkl".format(env_name),'wb') as fp:
        pkl.dump({"TIMEOUT":TIMEOUT,'cur_N':N},fp)
        
    for name,alg in algs.items():

        if timeouted[name]:
            continue
        
        print("Alg:", name, "N agent:",N)

        result = {}
        
        t0 = time()
        plan = alg(HG)
        t = time()-t0
        
        result['plan'] = plan
        result['time'] = t

        result['N_agent'] = N
        result['alg_name'] = name

        result["TIMEOUT"]=TIMEOUT
        result["HG"]=HG

        results.append(result)

        
        if t>TIMEOUT:
            timeouted[name] = True
            print("Time out for algorithm", name, "N agent = ", N)

    # Save checkpoint data
    with open("./data/{}.pkl".format(env_name),'wb') as fp:
        pkl.dump(results,fp)
# Out:
# Constructing environment
# /Users/tianpengzhang/opt/miniconda3/envs/PA-NAV/lib/python3.11/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# /Users/tianpengzhang/opt/miniconda3/envs/PA-NAV/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# PBS Time Elapsed: 53.81250190734863
# PBS Time Elapsed: 54.285786151885986
# PBS Time Elapsed: 55.21182417869568
# PBS Time Elapsed: 55.878698110580444
# PBS Time Elapsed: 57.30658316612244
# PBS Time Elapsed: 58.282050132751465
# PBS Time Elapsed: 59.186038970947266
# PBS Time Elapsed: 60.08885598182678
# PBS Time Elapsed: 61.095510959625244
# PBS Time Elapsed: 61.55677604675293
# PBS Time Elapsed: 62.42672109603882
# PBS Time Elapsed: 63.12617802619934
# PBS Time Elapsed: 64.25671601295471
# PBS Time Elapsed: 65.16363501548767
# PBS Time Elapsed: 66.06723618507385
# PBS Time Elapsed: 66.97438597679138
# PBS Time Elapsed: 67.62904500961304
# PBS Time Elapsed: 68.08729004859924
# PBS Time Elapsed: 68.9977970123291
# PBS Time Elapsed: 69.65568113327026
# PBS Time Elapsed: 70.82345914840698
# PBS Time Elapsed: 71.72859120368958
# PBS Time Elapsed: 72.63682007789612
# PBS Time Elapsed: 74.26646089553833
# PBS Time Elapsed: 75.7433569431305
# PBS Time Elapsed: 76.16200804710388
# PBS Time Elapsed: 77.07043194770813
# PBS Time Elapsed: 77.76816511154175
# PBS Time Elapsed: 78.89519214630127
# PBS Time Elapsed: 79.80632185935974
# PBS Time Elapsed: 80.71304202079773
# PBS Time Elapsed: 81.66428112983704
# PBS Time Elapsed: 82.71940803527832
# PBS Time Elapsed: 83.65405702590942
# PBS Time Elapsed: 84.57297682762146
# PBS Time Elapsed: 85.2768042087555
# PBS Time Elapsed: 86.1780788898468
# PBS Time Elapsed: 87.3568058013916
# PBS Time Elapsed: 88.30349111557007
# PBS Time Elapsed: 89.46985912322998
# PBS Time Elapsed: 90.44854998588562
# PBS Time Elapsed: 92.35626697540283
# PBS Time Elapsed: 93.0520510673523
# PBS Time Elapsed: 93.92143321037292
# PBS Time Elapsed: 94.93347311019897
# PBS Time Elapsed: 95.59639096260071
# PBS Time Elapsed: 96.50233006477356
# PBS Time Elapsed: 97.19833302497864
# PBS Time Elapsed: 98.32613205909729
# PBS Time Elapsed: 99.22776198387146
# PBS Time Elapsed: 100.3857650756836
# Time out for algorithm PBS_Tube N agent =  20
# Alg: TAHP N agent: 20
# Planning for 0/20
# Problem becomes infeasible.
# Alg: Seq_Tube N agent: 20
# Planning for agent 0/20
# Planning for agent 1/20
# Planning for agent 2/20
# Planning for agent 3/20
# Planning for agent 4/20
# Planning for agent 5/20
# Planning for agent 6/20
# Planning for agent 7/20
# Planning for agent 8/20
# Planning for agent 9/20
# Planning for agent 10/20
# Planning for agent 11/20
# Planning for agent 12/20
# Planning for agent 13/20
# Planning for agent 14/20
# Planning for agent 15/20
# Planning for agent 16/20
# Planning for agent 17/20
# Planning for agent 18/20
# Planning for agent 19/20
# Constructing environment
# Alg: PIBT N agent: 30
# Alg: TAHP N agent: 30
# Planning for 0/30
# Problem becomes infeasible.
# Alg: Seq_Tube N agent: 30
# Planning for agent 0/30
# Planning for agent 1/30
# Planning for agent 2/30
# Planning for agent 3/30
# Planning for agent 4/30
# Planning for agent 5/30
# Planning for agent 6/30
# Planning for agent 7/30
# Planning for agent 8/30
# Planning for agent 9/30
# Planning for agent 10/30
# Planning for agent 11/30
# Planning for agent 12/30
# Planning for agent 13/30
# Planning for agent 14/30
# Planning for agent 15/30
# Planning for agent 16/30
# Planning for agent 17/30
# Planning for agent 18/30
# Planning for agent 19/30
# Planning for agent 20/30
# Planning for agent 21/30
# Planning for agent 22/30
# Planning for agent 23/30
# Planning for agent 24/30
# Planning for agent 25/30
# Planning for agent 26/30
# Planning for agent 27/30
# Planning for agent 28/30
# Planning for agent 29/30
# Constructing environment
# Alg: PIBT N agent: 40
# Alg: TAHP N agent: 40
# Planning for 0/40
# Problem becomes infeasible.
# Alg: Seq_Tube N agent: 40
# Planning for agent 0/40
# Planning for agent 1/40
# Planning for agent 2/40
# Planning for agent 3/40
# Planning for agent 4/40
# Planning for agent 5/40
# Planning for agent 6/40
# Planning for agent 7/40
# Planning for agent 8/40
# Planning for agent 9/40
# Planning for agent 10/40
# Planning for agent 11/40
# Planning for agent 12/40
# Planning for agent 13/40
# Planning for agent 14/40
# Planning for agent 15/40
# Planning for agent 16/40
# Planning for agent 17/40
# Planning for agent 18/40
# Planning for agent 19/40
# Planning for agent 20/40
# Planning for agent 21/40
# Planning for agent 22/40
# Planning for agent 23/40
# Planning for agent 24/40
# Planning for agent 25/40
# Planning for agent 26/40
# Planning for agent 27/40
# Planning for agent 28/40
# Planning for agent 29/40
# Planning for agent 30/40
# Planning for agent 31/40
# Planning for agent 32/40
# Planning for agent 33/40
# Planning for agent 34/40
# Planning for agent 35/40
# Planning for agent 36/40
# Planning for agent 37/40
# Planning for agent 38/40
# Planning for agent 39/40
# Constructing environment
# Alg: PIBT N agent: 50
# Alg: TAHP N agent: 50
# Planning for 0/50
# Problem becomes infeasible.
# Alg: Seq_Tube N agent: 50
# Planning for agent 0/50
# Planning for agent 1/50
# Planning for agent 2/50
# Planning for agent 3/50
# Planning for agent 4/50
# Planning for agent 5/50
# Planning for agent 6/50
# Planning for agent 7/50
# Planning for agent 8/50
# Planning for agent 9/50
# Planning for agent 10/50
# Planning for agent 11/50
# Planning for agent 12/50
# Planning for agent 13/50
# Planning for agent 14/50
# Planning for agent 15/50
# Planning for agent 16/50
# Planning for agent 17/50
# Planning for agent 18/50
# Planning for agent 19/50
# Planning for agent 20/50
# Planning for agent 21/50
# Planning for agent 22/50
# Planning for agent 23/50
# Planning for agent 24/50
# Planning for agent 25/50
# Planning for agent 26/50
# Planning for agent 27/50
# Planning for agent 28/50
# Planning for agent 29/50
# Planning for agent 30/50
# Planning for agent 31/50
# Planning for agent 32/50
# Planning for agent 33/50
# Planning for agent 34/50
# Planning for agent 35/50
# Planning for agent 36/50
# Planning for agent 37/50
# Planning for agent 38/50
# Planning for agent 39/50
# Planning for agent 40/50
# Planning for agent 41/50
# Planning for agent 42/50
# Planning for agent 43/50
# Planning for agent 44/50
# Planning for agent 45/50
# Planning for agent 46/50
# Planning for agent 47/50
# Planning for agent 48/50
# Planning for agent 49/50
# Constructing environment
# Alg: PIBT N agent: 60
# Alg: TAHP N agent: 60
# Planning for 0/60
# Problem becomes infeasible.
# Alg: Seq_Tube N agent: 60
# Planning for agent 0/60
# Planning for agent 1/60
# Planning for agent 2/60
# Planning for agent 3/60
# Planning for agent 4/60
# Planning for agent 5/60
# Planning for agent 6/60
# Planning for agent 7/60
# Planning for agent 8/60
# Planning for agent 9/60
# Planning for agent 10/60
# Planning for agent 11/60
# Planning for agent 12/60
# Planning for agent 13/60
# Planning for agent 14/60
# Planning for agent 15/60
# Planning for agent 16/60
# Planning for agent 17/60
# Planning for agent 18/60
# Planning for agent 19/60
# Planning for agent 20/60
# Planning for agent 21/60
# Planning for agent 22/60
# Planning for agent 23/60
# Planning for agent 24/60
# Planning for agent 25/60
# Planning for agent 26/60
# Planning for agent 27/60
# Planning for agent 28/60
# Planning for agent 29/60
# Planning for agent 30/60
# Planning for agent 31/60
# Planning for agent 32/60
# Planning for agent 33/60
# Planning for agent 34/60
# Planning for agent 35/60
# Planning for agent 36/60
# Planning for agent 37/60
# Planning for agent 38/60
# Planning for agent 39/60
# Planning for agent 40/60
# Planning for agent 41/60
# Planning for agent 42/60
# Planning for agent 43/60
# Planning for agent 44/60
# Planning for agent 45/60
# Planning for agent 46/60
# Planning for agent 47/60
# Planning for agent 48/60
# Planning for agent 49/60
# Planning for agent 50/60
# Planning for agent 51/60
# Planning for agent 52/60
# Planning for agent 53/60
# Planning for agent 54/60
# Planning for agent 55/60
# Planning for agent 56/60
# Planning for agent 57/60
# Planning for agent 58/60
# Planning for agent 59/60
# Constructing environment
# Alg: PIBT N agent: 70
# Alg: TAHP N agent: 70
# Planning for 0/70
# Problem becomes infeasible.
# Alg: Seq_Tube N agent: 70
# Planning for agent 0/70
# Planning for agent 1/70
# Planning for agent 2/70
# Planning for agent 3/70
# Planning for agent 4/70
# Planning for agent 5/70
# Planning for agent 6/70
# Planning for agent 7/70
# Planning for agent 8/70
# Planning for agent 9/70
# Planning for agent 10/70
# Planning for agent 11/70
# Planning for agent 12/70
# Planning for agent 13/70
# Planning for agent 14/70
# Planning for agent 15/70
# Planning for agent 16/70
# Planning for agent 17/70
# Planning for agent 18/70
# Planning for agent 19/70
# Planning for agent 20/70
# Planning for agent 21/70
# Planning for agent 22/70
# Planning for agent 23/70
# Planning for agent 24/70
# Planning for agent 25/70
# Planning for agent 26/70
# Planning for agent 27/70
# Planning for agent 28/70
# Planning for agent 29/70
# Planning for agent 30/70
# Planning for agent 31/70
# Planning for agent 32/70
# Planning for agent 33/70
# Planning for agent 34/70
# Planning for agent 35/70
# Planning for agent 36/70
# Planning for agent 37/70
# Planning for agent 38/70
# Planning for agent 39/70
# Planning for agent 40/70
# Planning for agent 41/70
# Planning for agent 42/70
# Planning for agent 43/70
# Planning for agent 44/70
# Planning for agent 45/70
# Planning for agent 46/70
# Planning for agent 47/70
# Planning for agent 48/70
# Planning for agent 49/70
# Planning for agent 50/70
# Planning for agent 51/70
# Planning for agent 52/70
# Planning for agent 53/70
# Planning for agent 54/70
# Planning for agent 55/70
# Time out for algorithm Seq_Tube N agent =  70
# Constructing environment
# Alg: PIBT N agent: 80
# Alg: TAHP N agent: 80
# Planning for 0/80
# Problem becomes infeasible.
# Constructing environment
# Alg: PIBT N agent: 90
# Alg: TAHP N agent: 90
# Planning for 0/90
# Problem becomes infeasible.
# Constructing environment
# Alg: PIBT N agent: 100
# Alg: TAHP N agent: 100
# Planning for 0/100
# Problem becomes infeasible.
